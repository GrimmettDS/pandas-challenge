# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to Load
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
# Combine the data into a single dataset.
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
schools = school_data_complete['school_name'].unique()
school_count = len(schools)
school_count
# Out:
# 15

# %%
students = school_data_complete['student_name'].count()
students
# Out:
# 39170

# %%
budget = school_data_complete['budget'].unique()
budget_sum = budget.sum()
budget_sum
# Out:
# 24649428

# %%
avg_math_score = school_data_complete['math_score'].sum() / students
avg_math_score
# Out:
# 78.98537145774827

# %%
avg_reading_score = school_data_complete['reading_score'].sum() / students
avg_reading_score
# Out:
# 81.87784018381414

# %%
pass_math = school_data_complete[school_data_complete["math_score"]>= 70]
pass_math_count = pass_math["student_name"].count()
pass_math_pct = (pass_math_count / students) * 100
pass_math_pct
# Out:
# 74.9808526933878

# %%
pass_reading = school_data_complete[school_data_complete["reading_score"]>= 70]
pass_reading_count = pass_reading["student_name"].count()
pass_reading_pct = (pass_reading_count / students) * 100
pass_reading_pct
# Out:
# 85.80546336482001

# %%
pass_both = school_data_complete.loc[(school_data_complete['math_score'] >= 70) & 
                                     (school_data_complete['reading_score'] >= 70), :]
pass_both = pass_both["Student ID"].count()
#pass_both
#len(pass_both) - without this the number is 25528
pass_both_pct = (pass_both / students) * 100
pass_both_pct
# Out:
# 65.17232575950983

# %%
# Creating a summary DataFrame using above values
summary_df = pd.DataFrame({"Total Schools":[school_count],
                          "Total Students":[students],
                          "Total Budget": [budget_sum],
                          "Average Math Score": [avg_math_score],
                          "Average Reading Score": [avg_reading_score],
                          "% Passing Math": [pass_math_pct],
                          "% Passing Reading": [pass_reading_pct],
                          "% Overall Passing": [pass_both_pct],
                          })
summary_df["Total Students"] = summary_df["Total Students"].map('{:,}'.format)
summary_df["Total Budget"] = summary_df["Total Budget"].map('${:,.2f}'.format)
summary_df["Average Math Score"] = summary_df["Average Math Score"].map('{:.3f}'.format)
summary_df["Average Reading Score"] = summary_df["Average Reading Score"].map('{:.3f}'.format)
summary_df["% Passing Math"] = summary_df["% Passing Math"].map('{:.2f}%'.format)
summary_df["% Passing Reading"] = summary_df["% Passing Reading"].map('{:.2f}%'.format)
summary_df["% Overall Passing"] = summary_df["% Overall Passing"].map('{:.2f}%'.format)

summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00             78.985
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                81.878         74.98%            85.81%            65.17%

# %%
#groups by school
index_by_school = school_data_complete.set_index('school_name').groupby(['school_name'])

#school types
sch_types = school_data.set_index('school_name')['type']

# total students by school
stu_per_sch = index_by_school['Student ID'].count()

# school budget
sch_budget = school_data.set_index('school_name')['budget']

#per student budget
stu_budget = school_data.set_index('school_name')['budget']/school_data.set_index('school_name')['size']

#avg scores by school
avg_math = index_by_school['math_score'].mean()
avg_reading = index_by_school['reading_score'].mean()

# % passing scores
pass_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 
pass_reading = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 
pass_both = school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/stu_per_sch

pass_math = pass_math * 100
pass_reading = pass_reading * 100
pass_both = pass_both * 100

school_summary = pd.DataFrame({"School Type": sch_types,
                            "Total Students": stu_per_sch,
                            "Total School Budget": sch_budget,
                            "Per Student Budget": stu_budget,
                            "Average Math Score": avg_math,
                            "Average Reading Score": avg_reading,
                            "% Passing Math": pass_math,
                            "% Passing Reading": pass_reading,
                            "Overall Passing Rate": pass_both})

school_summary["Total Students"] = school_summary["Total Students"].map('{:,}'.format)
school_summary["Total School Budget"] = school_summary["Total School Budget"].map('${:,.2f}'.format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map('${:,.2f}'.format)
school_summary["Average Math Score"] = school_summary["Average Math Score"].map('{:.3f}'.format)
school_summary["Average Reading Score"] = school_summary["Average Reading Score"].map('{:.3f}'.format)
school_summary["% Passing Math"] = school_summary["% Passing Math"].map('{:.2f}%'.format)
school_summary["% Passing Reading"] = school_summary["% Passing Reading"].map('{:.2f}%'.format)
school_summary["Overall Passing Rate"] = school_summary["Overall Passing Rate"].map('{:.2f}%'.format)

school_summary
# Out:
#                       School Type Total Students Total School Budget  \
# Bailey High School       District          4,976       $3,124,928.00
# Cabrera High School       Charter          1,858       $1,081,356.00
# Figueroa High School     District          2,949       $1,884,411.00
# Ford High School         District          2,739       $1,763,916.00
# Griffin High School       Charter          1,468         $917,500.00
# Hernandez High School    District          4,635       $3,022,020.00
# Holden High School        Charter            427         $248,087.00
# Huang High School        District          2,917       $1,910,635.00
# Johnson High School      District          4,761       $3,094,650.00
# Pena High School          Charter            962         $585,858.00
# Rodriguez High School    District          3,999       $2,547,363.00
# Shelton High School       Charter          1,761       $1,056,600.00
# Thomas High School        Charter          1,635       $1,043,130.00
# ...

# %% [markdown]
# ### Top Performing Schools (By % Overall Passing)

# %%
# Sort and display the top five performing schools by % overall passing.

top_perf_overall = school_summary.sort_values("Overall Passing Rate", ascending=False)
top_perf_overall.head()
# Out:
#                     School Type Total Students Total School Budget  \
# Cabrera High School     Charter          1,858       $1,081,356.00
# Thomas High School      Charter          1,635       $1,043,130.00
# Griffin High School     Charter          1,468         $917,500.00
# Wilson High School      Charter          2,283       $1,319,574.00
# Pena High School        Charter            962         $585,858.00
#
#                     Per Student Budget Average Math Score  \
# Cabrera High School            $582.00             83.062
# Thomas High School             $638.00             83.418
# Griffin High School            $625.00             83.351
# Wilson High School             $578.00             83.274
# Pena High School               $609.00             83.840
#
#                     Average Reading Score % Passing Math % Passing Reading  \
# Cabrera High School                83.976         94.13%            97.04%
# ...

# %% [markdown]
# ### Bottom Performing Schools (By % Overall Passing)

# %%
# Sort and display the five worst-performing schools by % overall passing.

bot_perf_overall = school_summary.sort_values("Overall Passing Rate", ascending=True)
bot_perf_overall.head()
# Out:
#                       School Type Total Students Total School Budget  \
# Rodriguez High School    District          3,999       $2,547,363.00
# Figueroa High School     District          2,949       $1,884,411.00
# Huang High School        District          2,917       $1,910,635.00
# Hernandez High School    District          4,635       $3,022,020.00
# Johnson High School      District          4,761       $3,094,650.00
#
#                       Per Student Budget Average Math Score  \
# Rodriguez High School            $637.00             76.843
# Figueroa High School             $639.00             76.712
# Huang High School                $655.00             76.629
# Hernandez High School            $652.00             77.290
# Johnson High School              $650.00             77.072
#
#                       Average Reading Score % Passing Math % Passing Reading  \
# Rodriguez High School                80.745         66.37%            80.22%
# ...

# %% [markdown]
# ### Math Scores by Grade

# %%
# Create a table that lists the average Reading Score for students for each grade level (9th, 10th, 11th, 12th) at each school.
    # Create a pandas series for each grade.  Hint: use a conditional statement.
    # Group each series by school.
    # Combine the series into a dataframe.
    # Optional: give the displayed data cleaner formatting

ninth_grade_math = student_data.loc[student_data['grade'] == '9th'].groupby('school_name')["math_score"].mean()
#ninth_grade_math

tenth_grade_math = student_data.loc[student_data['grade'] == '10th'].groupby('school_name')["math_score"].mean()
#tenth_grade_math

eleventh_grade_math = student_data.loc[student_data['grade'] == '11th'].groupby('school_name')["math_score"].mean()
#eleventh_grade_math

twelfth_grade_math = student_data.loc[student_data['grade'] == '12th'].groupby('school_name')["math_score"].mean()
#twelfth_grade_math

# %%
math_scores_bygrade = pd.DataFrame({"9th": ninth_grade_math,
                                   "10th": tenth_grade_math,
                                   "11th": eleventh_grade_math,
                                   "12th": twelfth_grade_math})

math_scores_bygrade.index.name = ""

math_scores_bygrade["9th"] = math_scores_bygrade["9th"].map('{:.2f}'.format)
math_scores_bygrade["10th"] = math_scores_bygrade["10th"].map('{:.2f}'.format)
math_scores_bygrade["11th"] = math_scores_bygrade["11th"].map('{:.2f}'.format)
math_scores_bygrade["12th"] = math_scores_bygrade["12th"].map('{:.2f}'.format)

math_scores_bygrade
# Out:
#                          9th   10th   11th   12th
#
# Bailey High School     77.08  77.00  77.52  76.49
# Cabrera High School    83.09  83.15  82.77  83.28
# Figueroa High School   76.40  76.54  76.88  77.15
# Ford High School       77.36  77.67  76.92  76.18
# Griffin High School    82.04  84.23  83.84  83.36
# Hernandez High School  77.44  77.34  77.14  77.19
# Holden High School     83.79  83.43  85.00  82.86
# Huang High School      77.03  75.91  76.45  77.23
# Johnson High School    77.19  76.69  77.49  76.86
# Pena High School       83.63  83.37  84.33  84.12
# Rodriguez High School  76.86  76.61  76.40  77.69
# Shelton High School    83.42  82.92  83.38  83.78
# Thomas High School     83.59  83.09  83.50  83.50
# Wilson High School     83.09  83.72  83.20  83.04
# Wright High School     83.26  84.01  83.84  83.64

# %% [markdown]
# ### Reading Score by Grade

# %%
# Perform the same operations as above for reading scores.

ninth_grade_reading = student_data.loc[student_data['grade'] == '9th'].groupby('school_name')["reading_score"].mean()
#ninth_grade_reading

tenth_grade_reading = student_data.loc[student_data['grade'] == '10th'].groupby('school_name')["reading_score"].mean()
#tenth_grade_reading

eleventh_grade_reading = student_data.loc[student_data['grade'] == '11th'].groupby('school_name')["reading_score"].mean()
#eleventh_grade_reading

twelfth_grade_reading = student_data.loc[student_data['grade'] == '12th'].groupby('school_name')["reading_score"].mean()
#twelfth_grade_reading

# %%
reading_scores_bygrade = pd.DataFrame({"9th": ninth_grade_reading,
                                   "10th": tenth_grade_reading,
                                   "11th": eleventh_grade_reading,
                                   "12th": twelfth_grade_reading})

reading_scores_bygrade.index.name = ""

reading_scores_bygrade["9th"] = reading_scores_bygrade["9th"].map('{:.2f}'.format)
reading_scores_bygrade["10th"] = reading_scores_bygrade["10th"].map('{:.2f}'.format)
reading_scores_bygrade["11th"] = reading_scores_bygrade["11th"].map('{:.2f}'.format)
reading_scores_bygrade["12th"] = reading_scores_bygrade["12th"].map('{:.2f}'.format)

reading_scores_bygrade
# Out:
#                          9th   10th   11th   12th
#
# Bailey High School     81.30  80.91  80.95  80.91
# Cabrera High School    83.68  84.25  83.79  84.29
# Figueroa High School   81.20  81.41  80.64  81.38
# Ford High School       80.63  81.26  80.40  80.66
# Griffin High School    83.37  83.71  84.29  84.01
# Hernandez High School  80.87  80.66  81.40  80.86
# Holden High School     83.68  83.32  83.82  84.70
# Huang High School      81.29  81.51  81.42  80.31
# Johnson High School    81.26  80.77  80.62  81.23
# Pena High School       83.81  83.61  84.34  84.59
# Rodriguez High School  80.99  80.63  80.86  80.38
# Shelton High School    84.12  83.44  84.37  82.78
# Thomas High School     83.73  84.25  83.59  83.83
# Wilson High School     83.94  84.02  83.76  84.32
# Wright High School     83.83  83.81  84.16  84.07

# %%
# Create a table that breaks down school performances based on average Spending Ranges (Per Student). 
# Use 4 reasonable bins to group school spending.  Include in the table each of the following:
    # Average Math Score
    # Average Reading Score
    # % Passing Math
    # % Passing Reading
    # Overall Passing Rate (Average of the above two)

spend_bins = [0, 585, 630, 645, 680]
spend_grp_names = ['< 585', '$586-630', '$630-645', '$646-680']

# %%
school_data_complete['spend_bins'] = pd.cut(school_data_complete['budget']/school_data_complete['size'], bins=spend_bins, labels=spend_grp_names)
school_data_complete.head()

#FAILED ATTEMPTS
#school_summary["Spending Ranges (Per Student)"] = pd.cut(stu_budget, bins=spend_bins, labels=spend_grp_names)
#school_summary.head(20)

#bins_school_spending = pd.cut(school_summary['Per Student Budget'], bins=spend_bins, labels=spend_grp_names)
#bins_school_spending = pd.DataFrame(bins_school_spending)
#school_summary['Spending Rangers (Per Student)'] = bins_school_spending
#bins_school_spending.columns

#school_data_complete['Spending Ranges'] = pd.cut(stu_budget, bins=spend_bins, labels=spend_grp_names)
#school_spend = school_data_complete.groupby('Spending Ranges')
#school_spend
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget spend_bins
# 0             66          79          0  District  2917  1910635   $646-680
# 1             94          61          0  District  2917  1910635   $646-680
# 2             90          60          0  District  2917  1910635   $646-680
# 3             67          58          0  District  2917  1910635   $646-680
# 4             97          84          0  District  2917  1910635   $646-680

# %%
score_by_spend = school_data_complete.groupby('spend_bins')

# %%
avg_math_spent = score_by_spend['math_score'].mean()
avg_math_spent.head()
# Out:
# spend_bins
# < 585       83.363065
# $586-630    79.982873
# $630-645    77.821056
# $646-680    77.049297
# Name: math_score, dtype: float64

# %%
avg_reading_spent = score_by_spend['reading_score'].mean()
avg_reading_spent.head()
# Out:
# spend_bins
# < 585       83.964039
# $586-630    82.312643
# $630-645    81.301007
# $646-680    81.005604
# Name: reading_score, dtype: float64

# %%
spent_pass_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('spend_bins')['Student ID'].count()/score_by_spend['Student ID'].count()
spent_pass_math.head()
# Out:
# spend_bins
# < 585       0.937029
# $586-630    0.791099
# $630-645    0.706236
# $646-680    0.662308
# Name: Student ID, dtype: float64

# %%
spent_pass_reading = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('spend_bins')['Student ID'].count()/score_by_spend['Student ID'].count()
spent_pass_reading.head()
# Out:
# spend_bins
# < 585       0.966866
# $586-630    0.885131
# $630-645    0.826002
# $646-680    0.811094
# Name: Student ID, dtype: float64

# %%
spent_overall = school_data_complete[(school_data_complete['math_score'] >= 70) & (school_data_complete['reading_score'] >= 70)].groupby('spend_bins')['Student ID'].count()/score_by_spend['Student ID'].count()
spent_overall.head()
# Out:
# spend_bins
# < 585       0.906407
# $586-630    0.709392
# $630-645    0.588412
# $646-680    0.535288
# Name: Student ID, dtype: float64

# %%
scores_by_money_spent = pd.DataFrame({"Average Math Score": avg_math_spent,
                                     "Average Reading Score": avg_reading_spent,
                                     "% Passing Math": spent_pass_math,
                                     "% Passing Reading": spent_pass_reading,
                                     "Overall Passing Rate": spent_overall})

scores_by_money_spent.index.name = "Spending Ranges (Per Student)"

scores_by_money_spent
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# < 585                                   83.363065              83.964039
# $586-630                                79.982873              82.312643
# $630-645                                77.821056              81.301007
# $646-680                                77.049297              81.005604
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# < 585                                0.937029           0.966866
# $586-630                             0.791099           0.885131
# $630-645                             0.706236           0.826002
# $646-680                             0.662308           0.811094
#
#                                Overall Passing Rate
# Spending Ranges (Per Student)
# < 585                                      0.906407
# $586-630                                   0.709392
# ...

# %%
size_bins = [0, 1000, 2000, 5000]
size_grp_names = ['Small (< 1000)', 'Medium (1000-2000)', 'Large (2000-5000)']

# %%
school_data_complete['size_bins'] = pd.cut(school_data_complete['size'], bins=size_bins, labels=size_grp_names)
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget spend_bins  \
# 0             66          79          0  District  2917  1910635   $646-680
# 1             94          61          0  District  2917  1910635   $646-680
# 2             90          60          0  District  2917  1910635   $646-680
# 3             67          58          0  District  2917  1910635   $646-680
# 4             97          84          0  District  2917  1910635   $646-680
#
#            size_bins
# 0  Large (2000-5000)
# 1  Large (2000-5000)
# 2  Large (2000-5000)
# 3  Large (2000-5000)
# ...

# %%
score_by_size = school_data_complete.groupby('size_bins')

# %%
avg_math_size = score_by_size['math_score'].mean()
avg_math_size.head()
# Out:
# size_bins
# Small (< 1000)        83.828654
# Medium (1000-2000)    83.372682
# Large (2000-5000)     77.477597
# Name: math_score, dtype: float64

# %%
avg_reading_size = score_by_size['reading_score'].mean()
avg_reading_size.head()
# Out:
# size_bins
# Small (< 1000)        83.974082
# Medium (1000-2000)    83.867989
# Large (2000-5000)     81.198674
# Name: reading_score, dtype: float64

# %%
size_pass_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/score_by_size['Student ID'].count()
size_pass_math.head()
# Out:
# size_bins
# Small (< 1000)        0.939525
# Medium (1000-2000)    0.936165
# Large (2000-5000)     0.686524
# Name: Student ID, dtype: float64

# %%
size_pass_reading = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/score_by_size['Student ID'].count()
size_pass_reading.head()
# Out:
# size_bins
# Small (< 1000)        0.960403
# Medium (1000-2000)    0.967731
# Large (2000-5000)     0.821252
# Name: Student ID, dtype: float64

# %%
size_overall = school_data_complete[(school_data_complete['math_score'] >= 70) & (school_data_complete['reading_score'] >= 70)].groupby('size_bins')['Student ID'].count()/score_by_size['Student ID'].count()
size_overall.head()
# Out:
# size_bins
# Small (< 1000)        0.901368
# Medium (1000-2000)    0.906243
# Large (2000-5000)     0.565740
# Name: Student ID, dtype: float64

# %%
score_by_school_size = pd.DataFrame({"Average Math Score": avg_math_size,
                                     "Average Reading Score": avg_reading_size,
                                     "% Passing Math": size_pass_math,
                                     "% Passing Reading": size_pass_reading,
                                     "Overall Passing Rate": size_overall})

score_by_school_size.index.name = "School Size"

score_by_school_size
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (< 1000)               83.828654              83.974082        0.939525
# Medium (1000-2000)           83.372682              83.867989        0.936165
# Large (2000-5000)            77.477597              81.198674        0.686524
#
#                     % Passing Reading  Overall Passing Rate
# School Size
# Small (< 1000)               0.960403              0.901368
# Medium (1000-2000)           0.967731              0.906243
# Large (2000-5000)            0.821252              0.565740

# %%
score_by_type = school_data_complete.groupby('type')
score_by_type.head()
# Out:
#       Student ID       student_name gender grade          school_name  \
# 0              0       Paul Bradley      M   9th    Huang High School
# 1              1       Victor Smith      M  12th    Huang High School
# 2              2    Kevin Rodriguez      M  12th    Huang High School
# 3              3  Dr. Richard Scott      M  12th    Huang High School
# 4              4         Bonnie Ray      F   9th    Huang High School
# 5866        5866   Jamie Montgomery      F  12th  Shelton High School
# 5867        5867   Shannon Phillips      F  10th  Shelton High School
# 5868        5868        Todd Barber      M  11th  Shelton High School
# 5869        5869       Desiree King      F  12th  Shelton High School
# 5870        5870    Melissa Roberts      F  10th  Shelton High School
#
#       reading_score  math_score  School ID      type  size   budget  \
# 0                66          79          0  District  2917  1910635
# ...

# %%
avg_math_type = score_by_type['math_score'].mean()
avg_math_type.head()
# Out:
# type
# Charter     83.406183
# District    76.987026
# Name: math_score, dtype: float64

# %%
avg_reading_type = score_by_type['reading_score'].mean()
avg_reading_type.head()
# Out:
# type
# Charter     83.902821
# District    80.962485
# Name: reading_score, dtype: float64

# %%
type_pass_math_type = school_data_complete[school_data_complete['math_score'] >= 70].groupby('type')['Student ID'].count()/score_by_type['Student ID'].count()
type_pass_math.head()
# Out:
# type
# Charter     0.937018
# District    0.665184
# Name: Student ID, dtype: float64

# %%
type_pass_reading = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('type')['Student ID'].count()/score_by_type['Student ID'].count()
type_pass_reading.head()
# Out:
# type
# Charter     0.966459
# District    0.809052
# Name: Student ID, dtype: float64

# %%
type_overall = school_data_complete[(school_data_complete['math_score'] >= 70) & (school_data_complete['reading_score'] >= 70)].groupby('type')['Student ID'].count()/score_by_type['Student ID'].count()
type_overall.head()
# Out:
# type
# Charter     0.905609
# District    0.536959
# Name: Student ID, dtype: float64

# %%
score_by_school_type = pd.DataFrame({"Average Math Score": avg_math_type,
                                     "Average Reading Score": avg_reading_type,
                                     "% Passing Math": type_pass_math,
                                     "% Passing Reading": type_pass_reading,
                                     "Overall Passing Rate": type_overall})

score_by_school_type.index.name = "School Type"

score_by_school_type
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.406183              83.902821        0.937018
# District              76.987026              80.962485        0.665184
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter               0.966459              0.905609
# District              0.809052              0.536959
